# %%
# Create Project Structure for Stock AI Assistant
# Run this in Jupyter Notebook

import os
from pathlib import Path

# 定义项目根目录
project_root = Path("stock-ai-assistant")

# 1. 创建目录结构
directories = [
    project_root,
    project_root / "config",
    project_root / "data" / "financial_reports",
    project_root / "data" / "vector_store",
    project_root / "src",
    project_root / "src" / "core",
    project_root / "src" / "rag",
    project_root / "src" / "tools",
    project_root / "src" / "agents",
]

print("📁 创建目录结构...")
for directory in directories:
    directory.mkdir(parents=True, exist_ok=True)
    print(f"✅ {directory}")

# 2. 创建 __init__.py 文件
init_files = [
    project_root / "src" / "__init__.py",
    project_root / "config" / "__init__.py",
    project_root / "src" / "core" / "__init__.py",
    project_root / "src" / "rag" / "__init__.py",
    project_root / "src" / "tools" / "__init__.py",
    project_root / "src" / "agents" / "__init__.py",
]

print("\n📝 创建 __init__.py 文件...")
for file in init_files:
    file.touch()
    print(f"✅ {file}")
# Out:
# 📁 创建目录结构...
# ✅ stock-ai-assistant
# ✅ stock-ai-assistant\config
# ✅ stock-ai-assistant\data\financial_reports
# ✅ stock-ai-assistant\data\vector_store
# ✅ stock-ai-assistant\src
# ✅ stock-ai-assistant\src\core
# ✅ stock-ai-assistant\src\rag
# ✅ stock-ai-assistant\src\tools
# ✅ stock-ai-assistant\src\agents
#
# 📝 创建 __init__.py 文件...
# ✅ stock-ai-assistant\src\__init__.py
# ✅ stock-ai-assistant\config\__init__.py
# ✅ stock-ai-assistant\src\core\__init__.py
# ✅ stock-ai-assistant\src\rag\__init__.py
# ✅ stock-ai-assistant\src\tools\__init__.py
# ✅ stock-ai-assistant\src\agents\__init__.py
